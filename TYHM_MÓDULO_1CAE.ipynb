# %% [markdown]
# <a href="https://colab.research.google.com/github/Caetana01/modulo1/blob/main/TYHM_M%C3%93DULO_1CAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuaderno
# Aquí voy a meclar código MarkDown con operaciones matemáticas
#
#
# *   Suma
# *   Resta
# *   División
# *   Multiplicación

# %%
a=3
b=9
a+b
# Out:
# [1] 12

# %%
c=10
d=-8
d-c
# Out:
# [1] -18

# %%
a=1:100
b=a^2
plot(a, b, main="presión del gas crítico", xlab="volumen", ylab="presión", type="l", col="red")
# Out:
# Plot with title “presión del gas crítico”
